# %% [markdown]
# # Part C — Segment Economics
#
# Which categories and states are margin-negative once real freight cost is netted against real item price.

# %%
import sys; sys.path.insert(0, '../src')

# %%
from segments import build_segment_economics
by_cat, by_state = build_segment_economics()

# %% [markdown]
# ## Worst 5 categories by margin %

# %%
by_cat.head(5)[['n_items','avg_margin_pct','avg_freight_pct','avg_weight_g']]
# Out:
#                          n_items  avg_margin_pct  avg_freight_pct  \
# category
# home_comfort_2                30        0.066138         0.933862
# dvds_blu_ray                  62        0.161063         0.838937
# electronics                 2755        0.314504         0.685496
# christmas_supplies           152        0.323917         0.676083
# fashion_underwear_beach      131        0.434497         0.565503
#
#                          avg_weight_g
# category
# home_comfort_2             827.933333
# dvds_blu_ray               460.080645
# electronics                777.354265
# christmas_supplies        1904.855263
# fashion_underwear_beach    276.145038

# %% [markdown]
# ## Best 5 categories by margin %

# %%
by_cat.tail(5)[['n_items','avg_margin_pct','avg_freight_pct','avg_weight_g']]
# Out:
#                                        n_items  avg_margin_pct  \
# category
# home_confort                               434        0.788761
# home_appliances_2                          235        0.801587
# watches_gifts                             5970        0.829700
# small_appliances_home_oven_and_coffee       76        0.835650
# computers                                  203        0.943387
#
#                                        avg_freight_pct  avg_weight_g
# category
# home_confort                                  0.211239   3114.400922
# home_appliances_2                             0.198413   8946.761702
# watches_gifts                                 0.170300    581.563484
# small_appliances_home_oven_and_coffee         0.164350   5074.894737
# computers                                     0.056613   7216.798030

# %% [markdown]
# ## Worst 5 states by margin % (freight-distance effect)

# %%
by_state.head(5)[['n_items','avg_margin_pct','avg_freight_pct']]
# Out:
#                 n_items  avg_margin_pct  avg_freight_pct
# customer_state
# RO                  277        0.404503         0.595497
# RR                   51        0.404991         0.595009
# MA                  820        0.450321         0.549679
# PB                  600        0.487293         0.512707
# AC                   92        0.488349         0.511651

# %% [markdown]
# ## Best 5 states by margin %

# %%
by_state.tail(5)[['n_items','avg_margin_pct','avg_freight_pct']]
# Out:
#                 n_items  avg_margin_pct  avg_freight_pct
# customer_state
# DF                 2397        0.656109         0.343891
# MS                  818        0.660071         0.339929
# MG                13071        0.669166         0.330834
# RJ                14509        0.672338         0.327662
# SP                47153        0.734906         0.265094
